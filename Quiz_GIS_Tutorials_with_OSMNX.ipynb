# %% [markdown]
# <a href="https://colab.research.google.com/github/m0v3m1n/OSS_developing/blob/main/Quiz_GIS_Tutorials_with_OSMNX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 프로그램 설치
#
# 프로그램을 설치한뒤에, restart runtime을 실행한뒤에 2번째셀부터 이후 실행을 진행하시면 됩니다.

# %%
# !python -m pip uninstall numpy
# !pip install numpy==1.18
# !python -m pip uninstall matplotlib
# !pip install osmnx
# !pip install matplotlib
# !pip install descartes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: osmnx in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: geopandas>=0.12 in /usr/local/lib/python3.10/dist-packages (from osmnx) (0.13.0)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.7.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.1)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.24.3)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.5.3)
# Requirement already satisfied: pyproj>=3.4 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.8.2)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.31.0)
# Requirement already satisfied: Shapely>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (1.9.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->osmnx) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.4->osmnx) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8->osmnx) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx) (1.26.15)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (0.7.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import networkx as nx
import osmnx as ox
import matplotlib.pyplot as plt

# %matplotlib inline
# ox.config(log_console=True)
ox.__version__
# Out:
# '1.3.0'

# %% [markdown]
# # 도로 네트워크 작업해 보기
#
# 1. graph_from_place: 지역명
# 1. graph_from_address: 주소정보
# 1. graph_from_point: 위경도정보
# 1. graph_from_bbox: 동서남북좌표

# %%
# download/model a street network for some city then visualize it
place = "Yeongdo-gu, Busan, Korea"
G = ox.graph_from_place(place, network_type="drive")
fig, ax = ox.plot_graph(G)

# %%
# convert your MultiDiGraph to an undirected MultiGraph
M = ox.utils_graph.get_undirected(G)

# convert your MultiDiGraph to a DiGraph without parallel edges
D = ox.utils_graph.get_digraph(G)

# %%
for u, v, _, data in G.edges(data = True, keys = True) : 
  print(data)
# Out:
# {'osmid': 37403300, 'name': '상리로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 177.75}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 608.422, 'geometry': <LINESTRING (129.072 35.086, 129.072 35.087, 129.072 35.087, 129.071 35.088,...>}
# {'osmid': [281779718, 449880639], 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 173.613, 'geometry': <LINESTRING (129.072 35.086, 129.072 35.086, 129.072 35.086, 129.072 35.086,...>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': True, 'length': 196.038}
# {'osmid': 37396918, 'name': '동삼남로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 129.116, 'geometry': <LINESTRING (129.071 35.077, 129.07 35.078, 129.069 35.078, 129.069 35.078)>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': False, 'length': 179.007, 'geometry': <LINESTRING (129.071 35.077, 129.071 35.078, 129.07 35.079)>}
# {'osmid': 391431072, 'name': '근면길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 111.538}
# {'osmid': 37396918, 'name': '동삼남로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 32.221999999999994, 'geometry': <LINESTRING (129.066 35.077, 129.066 35.077, 129.066 35.077)>}
# {'osmid': 391422608, 'name': '근면길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 253.671, 'geometry': <LINESTRING (129.066 35.077, 129.066 35.078, 129.066 35.078, 129.066 35.078,...>}
# {'osmid': 391431072, 'name': '근면길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 111.538}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 46.397999999999996, 'geometry': <LINESTRING (129.066 35.076, 129.066 35.076, 129.065 35.076)>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 56.745, 'geometry': <LINESTRING (129.066 35.076, 129.066 35.076, 129.067 35.076)>}
# {'osmid': 391422616, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 63.706}
# {'osmid': 37396919, 'name': '번영길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 55.359, 'geometry': <LINESTRING (129.046 35.092, 129.046 35.092, 129.046 35.092)>}
# {'osmid': 165388588, 'name': '번영길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 69.387, 'geometry': <LINESTRING (129.046 35.092, 129.046 35.092, 129.046 35.093)>}
# {'osmid': 37397016, 'name': '동백꽃길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 170.523, 'geometry': <LINESTRING (129.049 35.092, 129.05 35.092, 129.051 35.092, 129.051 35.092)>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 142.697, 'geometry': <LINESTRING (129.049 35.092, 129.049 35.092, 129.048 35.091, 129.048 35.091,...>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 154.82999999999998, 'geometry': <LINESTRING (129.049 35.092, 129.05 35.092, 129.05 35.093, 129.05 35.093)>}
# {'osmid': 37397016, 'name': '동백꽃길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 170.523, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.05 35.092, 129.049 35.092)>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 32.225, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.051 35.092)>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 255.389, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.051 35.092, 129.05 35.092, ...>}
# {'osmid': 777392672, 'name': '개량1길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 10.105}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 40.41, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.052 35.092)>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 32.225, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.051 35.092)>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 285.422, 'geometry': <LINESTRING (129.055 35.092, 129.055 35.092, 129.055 35.092, 129.055 35.092,...>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 179.489, 'geometry': <LINESTRING (129.055 35.092, 129.054 35.092, 129.053 35.092)>}
# {'osmid': 165393195, 'name': '봉래길147번길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 249.355, 'geometry': <LINESTRING (129.055 35.092, 129.056 35.093, 129.057 35.092)>}
# {'osmid': 165393188, 'name': '청학서로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 155.905, 'geometry': <LINESTRING (129.057 35.091, 129.057 35.092, 129.057 35.092, 129.057 35.092,...>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 285.422, 'geometry': <LINESTRING (129.057 35.091, 129.057 35.091, 129.056 35.091, 129.056 35.091,...>}
# {'osmid': 391422617, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 115.249, 'geometry': <LINESTRING (129.057 35.091, 129.057 35.091, 129.057 35.091, 129.058 35.09, ...>}
# {'osmid': 165393188, 'name': '청학서로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 180.531, 'geometry': <LINESTRING (129.057 35.092, 129.057 35.093, 129.057 35.093, 129.057 35.093,...>}
# {'osmid': 165393188, 'name': '청학서로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 155.905, 'geometry': <LINESTRING (129.057 35.092, 129.057 35.092, 129.057 35.092, 129.057 35.092,...>}
# {'osmid': 165393195, 'name': '봉래길147번길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 249.355, 'geometry': <LINESTRING (129.057 35.092, 129.056 35.093, 129.055 35.092)>}
# {'osmid': 994830764, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 264.005, 'geometry': <LINESTRING (129.057 35.092, 129.058 35.092, 129.06 35.092)>}
# {'osmid': 165393188, 'name': '청학서로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 37.955}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 159.975, 'geometry': <LINESTRING (129.057 35.094, 129.056 35.094, 129.056 35.094, 129.055 35.094,...>}
# {'osmid': 165393188, 'name': '청학서로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 180.531, 'geometry': <LINESTRING (129.057 35.094, 129.057 35.094, 129.057 35.094, 129.057 35.094,...>}
# {'osmid': 391432774, 'name': '청학북로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 194.86800000000002, 'geometry': <LINESTRING (129.057 35.094, 129.057 35.094, 129.057 35.094, 129.058 35.094,...>}
# {'osmid': 37397635, 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 33.571}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 37.513}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 45.786}
# {'osmid': 655967799, 'name': '해양로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 64.569, 'geometry': <LINESTRING (129.079 35.071, 129.079 35.071, 129.079 35.072)>}
# {'osmid': 37397635, 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 76.695}
# {'osmid': 37397635, 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 33.571}
# {'osmid': 470919835, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 93.863}
# {'osmid': 761589240, 'highway': 'unclassified', 'oneway': False, 'reversed': False, 'length': 136.824}
# {'osmid': 761589240, 'highway': 'unclassified', 'oneway': False, 'reversed': True, 'length': 189.861}
# {'osmid': 455997172, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 371.34499999999997, 'geometry': <LINESTRING (129.086 35.074, 129.086 35.075, 129.086 35.075, 129.086 35.075,...>}
# {'osmid': 37399593, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 121.973}
# {'osmid': 37399740, 'name': '남항시장길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 16.417}
# {'osmid': 37399593, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 66.634, 'geometry': <LINESTRING (129.044 35.088, 129.044 35.087, 129.043 35.087)>}
# {'osmid': 165385958, 'name': '남항시장길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 129.324, 'geometry': <LINESTRING (129.044 35.088, 129.043 35.088, 129.043 35.088, 129.042 35.088)>}
# {'osmid': 37399593, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 68.43}
# {'osmid': 391422601, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 55.407}
# {'osmid': 391422616, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 112.711}
# {'osmid': 37399738, 'name': '남항새싹4길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 115.424}
# {'osmid': 37401954, 'name': '영선대로28번길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 128.576}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 70.308}
# {'osmid': 797760112, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 82.751}
# {'osmid': 37399738, 'name': '남항새싹4길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 115.424}
# {'osmid': 37399739, 'name': '남항새싹길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 47.043}
# {'osmid': 37399739, 'name': '남항새싹길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 45.515}
# {'osmid': 37399739, 'name': '남항새싹길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 11.567}
# {'osmid': 37399739, 'name': '남항새싹길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 53.155}
# {'osmid': 777381188, 'name': '남항새싹1길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 109.414}
# {'osmid': 37399740, 'name': '남항시장길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 124.19800000000001, 'geometry': <LINESTRING (129.047 35.088, 129.046 35.088, 129.045 35.088, 129.045 35.088)>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 78.26899999999999, 'geometry': <LINESTRING (129.047 35.088, 129.047 35.087, 129.046 35.087, 129.046 35.087,...>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 143.692, 'geometry': <LINESTRING (129.047 35.088, 129.047 35.088, 129.047 35.089)>}
# {'osmid': 165385957, 'name': '남항로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 48.569}
# {'osmid': 165385958, 'name': '남항시장길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 29.133}
# {'osmid': 165393966, 'oneway': True, 'name': '영선대로', 'highway': 'secondary', 'reversed': False, 'length': 139.08}
# {'osmid': 165385963, 'name': '대평로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 42.932}
# {'osmid': 674026489, 'name': '남항서로', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 54.167}
# {'osmid': 796491756, 'name': '남항로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 82.846}
# {'osmid': 796491757, 'name': '남항서로', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 54.212}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': False, 'length': 249.291, 'geometry': <LINESTRING (129.074 35.075, 129.074 35.075, 129.074 35.075, 129.073 35.075,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 372.077, 'geometry': <LINESTRING (129.074 35.075, 129.074 35.075, 129.074 35.075, 129.074 35.076,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 153.938, 'geometry': <LINESTRING (129.074 35.075, 129.074 35.075, 129.074 35.074, 129.074 35.074,...>}
# {'osmid': [1007861357, 1007861358, 391432775], 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 121.733, 'bridge': 'yes', 'geometry': <LINESTRING (129.074 35.075, 129.075 35.075, 129.075 35.075, 129.075 35.075)>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': False, 'length': 96.881}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': True, 'length': 166.722, 'geometry': <LINESTRING (129.071 35.082, 129.071 35.081, 129.07 35.081, 129.07 35.08)>}
# {'osmid': 165393178, 'name': '동삼동로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 236.32600000000002, 'geometry': <LINESTRING (129.071 35.082, 129.071 35.082, 129.071 35.082, 129.072 35.081,...>}
# {'osmid': 718033984, 'name': '동삼로93번길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 60.372, 'geometry': <LINESTRING (129.071 35.082, 129.07 35.082, 129.07 35.082)>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': False, 'length': 187.288, 'geometry': <LINESTRING (129.072 35.084, 129.072 35.084, 129.072 35.084, 129.072 35.084,...>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': True, 'length': 126.74599999999998, 'geometry': <LINESTRING (129.072 35.084, 129.072 35.083, 129.072 35.083, 129.071 35.083,...>}
# {'osmid': 165393196, 'name': '동삼서로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 241.30199999999994, 'geometry': <LINESTRING (129.072 35.084, 129.071 35.083, 129.071 35.083, 129.07 35.083, ...>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': True, 'length': 187.288, 'geometry': <LINESTRING (129.073 35.085, 129.073 35.085, 129.073 35.085, 129.072 35.084,...>}
# {'osmid': [281779718, 449880639], 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 173.613, 'geometry': <LINESTRING (129.073 35.085, 129.073 35.085, 129.072 35.085, 129.072 35.085,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 154.566, 'geometry': <LINESTRING (129.073 35.085, 129.073 35.085, 129.073 35.085, 129.073 35.085,...>}
# {'osmid': 391431070, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 278.29, 'geometry': <LINESTRING (129.071 35.075, 129.071 35.075, 129.071 35.075, 129.07 35.074, ...>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 208.574, 'geometry': <LINESTRING (129.071 35.075, 129.071 35.075, 129.071 35.075, 129.071 35.075,...>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 256.48400000000004, 'geometry': <LINESTRING (129.071 35.075, 129.071 35.075, 129.072 35.074, 129.072 35.073,...>}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 45.223}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 253.626, 'geometry': <LINESTRING (129.068 35.075, 129.068 35.076, 129.068 35.078)>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 129.66199999999998, 'geometry': <LINESTRING (129.068 35.075, 129.068 35.076, 129.068 35.076, 129.068 35.076,...>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 95.547, 'geometry': <LINESTRING (129.068 35.075, 129.068 35.075, 129.069 35.076, 129.069 35.076)>}
# {'osmid': 391431069, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 190.11, 'geometry': <LINESTRING (129.065 35.078, 129.064 35.078, 129.064 35.078, 129.064 35.079,...>}
# {'osmid': 391431069, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 210.336, 'geometry': <LINESTRING (129.065 35.078, 129.065 35.078, 129.065 35.077, 129.065 35.077,...>}
# {'osmid': 761773252, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 190.68900000000002, 'geometry': <LINESTRING (129.065 35.078, 129.064 35.078, 129.064 35.078, 129.064 35.078,...>}
# {'osmid': 165393186, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 20.241}
# {'osmid': 165393180, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 146.498, 'geometry': <LINESTRING (129.064 35.079, 129.064 35.08, 129.064 35.08, 129.064 35.08, 12...>}
# {'osmid': 391431069, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 190.10999999999999, 'geometry': <LINESTRING (129.064 35.079, 129.064 35.079, 129.064 35.079, 129.064 35.079,...>}
# {'osmid': 37400886, 'name': '봉래언덕길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 302.95400000000006, 'geometry': <LINESTRING (129.05 35.093, 129.049 35.093, 129.049 35.094, 129.049 35.094, ...>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 154.82999999999998, 'geometry': <LINESTRING (129.05 35.093, 129.05 35.093, 129.05 35.092, 129.049 35.092)>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 137.057, 'geometry': <LINESTRING (129.05 35.093, 129.05 35.093, 129.052 35.093)>}
# {'osmid': 37400886, 'name': '봉래언덕길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 28.948}
# {'osmid': 37400887, 'name': '봉래언덕길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 23.708}
# {'osmid': 37400886, 'name': '봉래언덕길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 302.954, 'geometry': <LINESTRING (129.047 35.094, 129.048 35.094, 129.048 35.094, 129.048 35.094,...>}
# {'osmid': 37400886, 'name': '봉래언덕길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 25.104}
# {'osmid': 511895517, 'oneway': True, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 103.77}
# {'osmid': 37400941, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 49.576}
# {'osmid': 511895516, 'oneway': False, 'lanes': '6', 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 60.435}
# {'osmid': 511895516, 'oneway': False, 'lanes': '6', 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 47.857}
# {'osmid': 796491755, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 58.834}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 39.128}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 148.994}
# {'osmid': 165393179, 'name': '산업로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 307.924, 'geometry': <LINESTRING (129.064 35.095, 129.065 35.095, 129.067 35.094)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 15.318}
# {'osmid': 37401140, 'oneway': True, 'highway': 'secondary', 'reversed': False, 'length': 33.003, 'geometry': <LINESTRING (129.074 35.081, 129.074 35.081, 129.075 35.081)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 35.102000000000004, 'geometry': <LINESTRING (129.074 35.081, 129.074 35.081, 129.074 35.08, 129.074 35.08)>}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 184.541, 'geometry': <LINESTRING (129.06 35.092, 129.06 35.093, 129.06 35.093, 129.06 35.094)>}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 182.84500000000003, 'geometry': <LINESTRING (129.06 35.092, 129.06 35.092, 129.06 35.092, 129.06 35.092, 129...>}
# {'osmid': [777381203, 391422611], 'name': ['청학남로13번길', '청학로35번길'], 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 245.95100000000002, 'geometry': <LINESTRING (129.06 35.092, 129.06 35.091, 129.059 35.091, 129.059 35.091, 1...>}
# {'osmid': 994830764, 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 264.005, 'geometry': <LINESTRING (129.06 35.092, 129.058 35.092, 129.057 35.092)>}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 34.447}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 184.541, 'geometry': <LINESTRING (129.06 35.094, 129.06 35.093, 129.06 35.093, 129.06 35.092)>}
# {'osmid': 500097031, 'name': '청학북로20번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 133.712, 'geometry': <LINESTRING (129.06 35.094, 129.059 35.094, 129.059 35.094, 129.059 35.094)>}
# {'osmid': 37401707, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 0.842}
# {'osmid': 391431070, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 254.953, 'geometry': <LINESTRING (129.066 35.074, 129.066 35.074, 129.066 35.074, 129.067 35.074,...>}
# {'osmid': 391431070, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 107.62799999999999, 'geometry': <LINESTRING (129.066 35.074, 129.066 35.074, 129.065 35.073, 129.065 35.073,...>}
# {'osmid': 391431071, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 53.008}
# {'osmid': 391431071, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 66.359}
# {'osmid': 37401707, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 330.807, 'geometry': <LINESTRING (129.065 35.076, 129.065 35.076, 129.065 35.076, 129.064 35.074,...>}
# {'osmid': 391431071, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 53.008}
# {'osmid': 391431069, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 210.336, 'geometry': <LINESTRING (129.065 35.076, 129.065 35.076, 129.065 35.077, 129.065 35.077,...>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 46.397999999999996, 'geometry': <LINESTRING (129.065 35.076, 129.066 35.076, 129.066 35.076)>}
# {'osmid': 37401791, 'name': '한결길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 280.602, 'geometry': <LINESTRING (129.046 35.091, 129.046 35.091, 129.046 35.091, 129.046 35.091,...>}
# {'osmid': 37401791, 'name': '한결길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 40.613, 'geometry': <LINESTRING (129.046 35.091, 129.046 35.091, 129.046 35.092)>}
# {'osmid': 165388590, 'name': '아리랑길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 92.798, 'geometry': <LINESTRING (129.046 35.091, 129.046 35.091, 129.047 35.092, 129.047 35.092,...>}
# {'osmid': 165388590, 'name': '아리랑길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 92.798, 'geometry': <LINESTRING (129.047 35.092, 129.047 35.092, 129.047 35.092, 129.047 35.092,...>}
# {'osmid': 37402486, 'name': '중리북로21번길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 253.34400000000002, 'geometry': <LINESTRING (129.065 35.073, 129.065 35.073, 129.065 35.073, 129.066 35.073,...>}
# {'osmid': 37402770, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 660.085, 'geometry': <LINESTRING (129.065 35.073, 129.065 35.073, 129.064 35.073, 129.064 35.072,...>}
# {'osmid': 391431070, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 107.628, 'geometry': <LINESTRING (129.065 35.073, 129.065 35.073, 129.065 35.073, 129.066 35.074,...>}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': False, 'length': 196.038}
# {'osmid': 37400208, 'oneway': False, 'lanes': '2', 'name': '동삼로', 'highway': 'secondary', 'reversed': True, 'length': 249.291, 'geometry': <LINESTRING (129.072 35.076, 129.072 35.076, 129.073 35.076, 129.073 35.075,...>}
# {'osmid': 37402577, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 453.421, 'geometry': <LINESTRING (129.072 35.076, 129.072 35.076, 129.072 35.076, 129.072 35.076,...>}
# {'osmid': 37402577, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 223.303, 'geometry': <LINESTRING (129.072 35.076, 129.072 35.076, 129.072 35.076, 129.072 35.077,...>}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 44.495}
# {'osmid': 165393177, 'oneway': True, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 107.155}
# {'osmid': 165393177, 'oneway': True, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 366.012, 'geometry': <LINESTRING (129.066 35.069, 129.069 35.071, 129.07 35.071)>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 85.98700000000001, 'geometry': <LINESTRING (129.066 35.069, 129.066 35.069, 129.066 35.069, 129.066 35.069,...>}
# {'osmid': 37402770, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 660.085, 'geometry': <LINESTRING (129.059 35.071, 129.059 35.071, 129.06 35.071, 129.061 35.071, ...>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 1692.1409999999998, 'geometry': <LINESTRING (129.059 35.071, 129.059 35.071, 129.058 35.071, 129.058 35.071,...>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 696.7529999999999, 'geometry': <LINESTRING (129.059 35.071, 129.059 35.071, 129.06 35.071, 129.06 35.07, 12...>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 44.931, 'geometry': <LINESTRING (129.045 35.08, 129.044 35.08, 129.044 35.08)>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 1692.141, 'geometry': <LINESTRING (129.045 35.08, 129.045 35.079, 129.046 35.078, 129.047 35.077, ...>}
# {'osmid': 624370417, 'oneway': True, 'highway': 'secondary_link', 'reversed': False, 'length': 92.801, 'geometry': <LINESTRING (129.045 35.08, 129.044 35.08, 129.044 35.08, 129.044 35.08, 129...>}
# {'osmid': 37399739, 'name': '남항새싹길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 31.27}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 34.516, 'geometry': <LINESTRING (129.043 35.08, 129.043 35.081, 129.043 35.081, 129.043 35.081)>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 96.21300000000001, 'geometry': <LINESTRING (129.043 35.08, 129.043 35.08, 129.044 35.08)>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 39.53}
# {'osmid': 391422606, 'name': '남항새싹6길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 113.151}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 193.139, 'geometry': <LINESTRING (129.041 35.082, 129.041 35.082, 129.041 35.082, 129.042 35.081,...>}
# {'osmid': 165386544, 'oneway': False, 'highway': 'secondary_link', 'reversed': False, 'length': 15.179}
# {'osmid': 165386548, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 29.738}
# {'osmid': 165386548, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 84.881}
# {'osmid': 165386548, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 29.789}
# {'osmid': 511894549, 'oneway': True, 'name': '영선대로', 'highway': 'secondary', 'reversed': False, 'length': 29.694}
# {'osmid': 511894550, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 36.864}
# {'osmid': 37402639, 'name': '대교로14번길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 71.022}
# {'osmid': 629875732, 'name': '대교로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 73.381}
# {'osmid': 629875732, 'name': '대교로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 79.097}
# {'osmid': 37402639, 'name': '대교로14번길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 90.75}
# {'osmid': 122355928, 'name': '대교로14번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 71.944}
# {'osmid': 37402639, 'name': '대교로14번길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 50.915, 'geometry': <LINESTRING (129.044 35.094, 129.044 35.094, 129.044 35.094)>}
# {'osmid': 122355926, 'name': '봉래나루로234번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 68.295}
# {'osmid': 165389006, 'name': '봉래나루로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 54.565}
# {'osmid': 165389006, 'name': '봉래나루로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 57.638}
# {'osmid': 37402486, 'name': '중리북로21번길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 253.344, 'geometry': <LINESTRING (129.067 35.071, 129.067 35.071, 129.067 35.071, 129.066 35.072,...>}
# {'osmid': 37402701, 'oneway': True, 'name': '중리북로', 'highway': 'secondary', 'reversed': False, 'length': 207.346, 'geometry': <LINESTRING (129.067 35.071, 129.067 35.071, 129.067 35.071, 129.067 35.07, ...>}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 44.495}
# {'osmid': 37402701, 'oneway': True, 'name': '중리북로', 'highway': 'secondary', 'reversed': False, 'length': 257.294, 'geometry': <LINESTRING (129.069 35.072, 129.069 35.072, 129.068 35.072, 129.068 35.072,...>}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 320.90600000000006, 'geometry': <LINESTRING (129.069 35.072, 129.068 35.074, 129.068 35.074, 129.068 35.074)>}
# {'osmid': 37402701, 'oneway': True, 'name': '중리북로', 'highway': 'secondary', 'reversed': False, 'length': 111.648, 'geometry': <LINESTRING (129.071 35.072, 129.07 35.072, 129.07 35.072, 129.069 35.072)>}
# {'osmid': 37402701, 'oneway': True, 'name': '중리북로', 'highway': 'secondary', 'reversed': False, 'length': 46.98, 'geometry': <LINESTRING (129.071 35.072, 129.071 35.072, 129.071 35.072)>}
# {'osmid': 800570336, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 148.911, 'geometry': <LINESTRING (129.071 35.072, 129.072 35.073, 129.072 35.073)>}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 60.946}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 320.906, 'geometry': <LINESTRING (129.068 35.074, 129.068 35.074, 129.068 35.074, 129.069 35.072)>}
# {'osmid': 391431070, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 278.2900000000001, 'geometry': <LINESTRING (129.068 35.074, 129.069 35.074, 129.069 35.074, 129.069 35.074,...>}
# {'osmid': 391431070, 'name': '함지로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 254.953, 'geometry': <LINESTRING (129.068 35.074, 129.068 35.074, 129.067 35.074, 129.066 35.074,...>}
# {'osmid': 37396918, 'name': '동삼남로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 4.841}
# {'osmid': 37396918, 'name': '동삼남로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 92.501}
# {'osmid': 37402704, 'name': '중리로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 253.626, 'geometry': <LINESTRING (129.068 35.078, 129.068 35.076, 129.068 35.075)>}
# {'osmid': 37396786, 'oneway': True, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 39.198}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 62.489999999999995, 'geometry': <LINESTRING (129.081 35.062, 129.081 35.062, 129.081 35.063)>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 12.223}
# {'osmid': 131451464, 'oneway': True, 'name': '본산로', 'highway': 'residential', 'reversed': False, 'length': 64.902, 'geometry': <LINESTRING (129.081 35.068, 129.08 35.068, 129.08 35.068)>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 60.270999999999994, 'geometry': <LINESTRING (129.081 35.068, 129.081 35.068, 129.081 35.068, 129.08 35.069, ...>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 13.303}
# {'osmid': 268374967, 'oneway': True, 'highway': 'unclassified', 'reversed': False, 'length': 12.987}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 38.342999999999996, 'geometry': <LINESTRING (129.08 35.069, 129.08 35.069, 129.08 35.069)>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 203.50800000000004, 'geometry': <LINESTRING (129.08 35.069, 129.08 35.069, 129.08 35.069, 129.08 35.069, 129...>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 38.342999999999996, 'geometry': <LINESTRING (129.08 35.069, 129.08 35.069, 129.08 35.069)>}
# {'osmid': 463039531, 'name': '하리해안길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 49.572, 'geometry': <LINESTRING (129.08 35.069, 129.08 35.069, 129.081 35.069)>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 37.513}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 203.508, 'geometry': <LINESTRING (129.079 35.071, 129.08 35.07, 129.08 35.07, 129.08 35.07, 129.0...>}
# {'osmid': 575122828, 'oneway': True, 'highway': 'residential', 'reversed': False, 'length': 55.584, 'geometry': <LINESTRING (129.079 35.071, 129.079 35.071, 129.079 35.071, 129.079 35.071)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 97.359, 'geometry': <LINESTRING (129.076 35.072, 129.076 35.072, 129.075 35.072)>}
# {'osmid': [643839808, 777381222], 'name': ['태종로', '태종로700번길'], 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 165.95, 'geometry': <LINESTRING (129.076 35.072, 129.076 35.072, 129.076 35.072, 129.076 35.072,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 249.794, 'geometry': <LINESTRING (129.076 35.072, 129.076 35.072, 129.076 35.072, 129.077 35.072,...>}
# {'osmid': 37400885, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 66.198}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 153.93800000000002, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.074, 129.074 35.074, 129.074 35.074,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 58.596999999999994, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.073)>}
# {'osmid': 37402577, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 223.30300000000003, 'geometry': <LINESTRING (129.073 35.078, 129.073 35.078, 129.073 35.078, 129.073 35.078,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 57.379000000000005, 'geometry': <LINESTRING (129.073 35.078, 129.073 35.078, 129.073 35.078)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 372.077, 'geometry': <LINESTRING (129.073 35.078, 129.073 35.078, 129.073 35.077, 129.073 35.077,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 14.233}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 35.102000000000004, 'geometry': <LINESTRING (129.074 35.08, 129.074 35.08, 129.074 35.081, 129.074 35.081)>}
# {'osmid': 692066525, 'oneway': True, 'highway': 'secondary_link', 'reversed': False, 'length': 51.436, 'geometry': <LINESTRING (129.074 35.08, 129.074 35.08, 129.074 35.08, 129.074 35.081, 12...>}
# {'osmid': 37401044, 'name': '해양로246번길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 217.819, 'geometry': <LINESTRING (129.074 35.084, 129.075 35.085, 129.075 35.085, 129.075 35.085,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 154.566, 'geometry': <LINESTRING (129.074 35.084, 129.074 35.085, 129.073 35.085, 129.073 35.085,...>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 613.425, 'geometry': <LINESTRING (129.074 35.084, 129.075 35.085, 129.076 35.084, 129.076 35.084,...>}
# {'osmid': 165393176, 'name': '일산봉로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 242.958, 'geometry': <LINESTRING (129.066 35.09, 129.066 35.09, 129.066 35.09, 129.065 35.09, 129...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 223.828, 'geometry': <LINESTRING (129.066 35.09, 129.066 35.091, 129.066 35.091, 129.066 35.091, ...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 49.93599999999999, 'geometry': <LINESTRING (129.066 35.09, 129.066 35.09, 129.066 35.09, 129.067 35.09, 129...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 148.994}
# {'osmid': 165393197, 'name': '청학동로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 376.06000000000006, 'geometry': <LINESTRING (129.065 35.094, 129.064 35.093, 129.064 35.093, 129.063 35.093,...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 248.289, 'geometry': <LINESTRING (129.065 35.094, 129.065 35.094, 129.065 35.093, 129.066 35.092)>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 37.129}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 214.469, 'geometry': <LINESTRING (129.061 35.097, 129.061 35.096, 129.061 35.096, 129.061 35.096,...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 131.041, 'geometry': <LINESTRING (129.061 35.097, 129.061 35.097, 129.062 35.096, 129.062 35.096)>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 18.944}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 9.61}
# {'osmid': 165393174, 'name': '태종로318번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 153.19299999999998, 'geometry': <LINESTRING (129.06 35.097, 129.06 35.097, 129.06 35.096, 129.06 35.096, 129...>}
# {'osmid': 122355922, 'name': '청학서로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 92.266}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 84.066}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 130.671, 'geometry': <LINESTRING (129.059 35.097, 129.059 35.098, 129.059 35.098, 129.058 35.098)>}
# {'osmid': 511890795, 'oneway': True, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 48.971}
# {'osmid': 511895517, 'oneway': True, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 186.558}
# {'osmid': 800593498, 'bridge': 'yes', 'oneway': True, 'name': '영도고가교', 'highway': 'trunk', 'reversed': False, 'length': 67.616, 'geometry': <LINESTRING (129.053 35.095, 129.053 35.095, 129.053 35.096, 129.053 35.096)>}
# {'osmid': 165393966, 'oneway': True, 'name': '영선대로', 'highway': 'secondary', 'reversed': False, 'length': 109.763}
# {'osmid': 391422601, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 30.779}
# {'osmid': 511895516, 'oneway': False, 'lanes': '6', 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 50.587}
# {'osmid': 511895516, 'oneway': False, 'lanes': '6', 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 87.511}
# {'osmid': 511895516, 'oneway': False, 'lanes': '6', 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 8.334}
# {'osmid': 674026489, 'name': '남항서로', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 50.805}
# {'osmid': 674026489, 'name': '남항서로', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 46.777}
# {'osmid': 674026489, 'name': '남항서로', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 77.696}
# {'osmid': 777392681, 'name': '절영로42번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 81.42}
# {'osmid': 796491758, 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 43.381}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 34.447}
# {'osmid': 391432774, 'name': '청학북로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 118.643}
# {'osmid': 37401449, 'name': '청학로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 119.67699999999999, 'geometry': <LINESTRING (129.06 35.094, 129.06 35.094, 129.06 35.094, 129.06 35.095, 129...>}
# {'osmid': 37403129, 'name': '청학북로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 33.483000000000004, 'geometry': <LINESTRING (129.06 35.094, 129.06 35.094, 129.06 35.094)>}
# {'osmid': 391432774, 'name': '청학북로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 118.643}
# {'osmid': 391430520, 'name': '청학로69번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 196.04000000000002, 'geometry': <LINESTRING (129.059 35.094, 129.059 35.094, 129.059 35.095, 129.059 35.095,...>}
# {'osmid': 391432774, 'name': '청학북로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 194.868, 'geometry': <LINESTRING (129.059 35.094, 129.058 35.094, 129.058 35.094, 129.057 35.094,...>}
# {'osmid': 500097031, 'name': '청학북로20번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 133.712, 'geometry': <LINESTRING (129.059 35.094, 129.059 35.094, 129.059 35.094, 129.06 35.094)>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 52.193}
# {'osmid': 37401791, 'name': '한결길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 280.602, 'geometry': <LINESTRING (129.048 35.091, 129.048 35.091, 129.048 35.091, 129.048 35.09, ...>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 142.697, 'geometry': <LINESTRING (129.048 35.091, 129.048 35.091, 129.048 35.091, 129.048 35.091,...>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 52.193}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 195.122, 'geometry': <LINESTRING (129.048 35.09, 129.047 35.089, 129.047 35.089)>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 72.004, 'geometry': <LINESTRING (129.048 35.09, 129.048 35.09, 129.049 35.09)>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': False, 'length': 214.49, 'geometry': <LINESTRING (129.046 35.086, 129.046 35.085, 129.046 35.085, 129.046 35.084,...>}
# {'osmid': 165393183, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 112.93900000000001, 'geometry': <LINESTRING (129.046 35.086, 129.046 35.086, 129.046 35.087, 129.046 35.087)>}
# {'osmid': 474280875, 'name': '나눔길', 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 277.443, 'geometry': <LINESTRING (129.046 35.086, 129.046 35.086, 129.046 35.086, 129.046 35.086,...>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 39.28, 'geometry': <LINESTRING (129.044 35.08, 129.044 35.08, 129.044 35.08)>}
# {'osmid': 165393181, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 44.931, 'geometry': <LINESTRING (129.044 35.08, 129.044 35.08, 129.045 35.08)>}
# {'osmid': 624370419, 'oneway': False, 'name': '하나길', 'highway': 'secondary', 'reversed': True, 'length': 66.834, 'geometry': <LINESTRING (129.044 35.08, 129.044 35.08, 129.044 35.08)>}
# {'osmid': 391422616, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 63.706}
# {'osmid': 391422616, 'name': '꿈나무길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 90.089}
# {'osmid': 37401791, 'name': '한결길', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 40.613, 'geometry': <LINESTRING (129.046 35.092, 129.046 35.091, 129.046 35.091)>}
# {'osmid': 37401791, 'name': '한결길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 59.80499999999999, 'geometry': <LINESTRING (129.046 35.092, 129.046 35.092, 129.045 35.092)>}
# {'osmid': 37400885, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 336.844, 'geometry': <LINESTRING (129.072 35.073, 129.073 35.072, 129.073 35.072, 129.073 35.072,...>}
# {'osmid': 37402577, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 453.421, 'geometry': <LINESTRING (129.072 35.073, 129.073 35.073, 129.073 35.073, 129.073 35.074,...>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 256.484, 'geometry': <LINESTRING (129.072 35.073, 129.072 35.073, 129.072 35.074, 129.071 35.075,...>}
# {'osmid': 800570336, 'oneway': False, 'lanes': '2', 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 148.911, 'geometry': <LINESTRING (129.072 35.073, 129.072 35.073, 129.071 35.072)>}
# {'osmid': 37401044, 'name': '해양로246번길', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 217.81900000000002, 'geometry': <LINESTRING (129.075 35.086, 129.075 35.086, 129.075 35.086, 129.075 35.085,...>}
# {'osmid': 74851185, 'oneway': False, 'name': '해양로', 'highway': 'secondary', 'reversed': False, 'length': 201.65500000000003, 'geometry': <LINESTRING (129.075 35.086, 129.075 35.086, 129.074 35.086, 129.074 35.086,...>}
# {'osmid': 281779717, 'oneway': False, 'name': '해양로', 'highway': 'secondary', 'reversed': True, 'length': 47.242000000000004, 'geometry': <LINESTRING (129.075 35.086, 129.076 35.086, 129.076 35.086, 129.076 35.086)>}
# ...
# {'osmid': 761589264, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 20.563}
# {'osmid': 165393186, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 20.241}
# {'osmid': [165393186, 761773253], 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 418.04600000000005, 'geometry': <LINESTRING (129.064 35.079, 129.063 35.079, 129.063 35.079, 129.063 35.079,...>}
# {'osmid': 761773252, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 190.689, 'geometry': <LINESTRING (129.064 35.079, 129.064 35.079, 129.064 35.079, 129.064 35.079,...>}
# {'osmid': 37401707, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 0.842}
# {'osmid': 37401707, 'name': '함지로79번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 330.80699999999996, 'geometry': <LINESTRING (129.066 35.074, 129.065 35.074, 129.065 35.074, 129.065 35.074,...>}
# {'osmid': 761780963, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 210.37399999999997, 'geometry': <LINESTRING (129.066 35.074, 129.065 35.074, 129.065 35.074, 129.065 35.074,...>}
# {'osmid': 761780963, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 21.224}
# {'osmid': 761780963, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 210.37400000000002, 'geometry': <LINESTRING (129.066 35.075, 129.066 35.075, 129.066 35.075, 129.066 35.075,...>}
# {'osmid': 761780964, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 108.394, 'geometry': <LINESTRING (129.066 35.075, 129.066 35.075, 129.066 35.076, 129.066 35.076,...>}
# {'osmid': 761780963, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 21.224}
# {'osmid': 761780964, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 78.436, 'geometry': <LINESTRING (129.067 35.076, 129.067 35.076, 129.067 35.076, 129.067 35.076,...>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 38.742000000000004, 'geometry': <LINESTRING (129.067 35.076, 129.067 35.076, 129.067 35.076, 129.067 35.076)>}
# {'osmid': 800570335, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 129.662, 'geometry': <LINESTRING (129.067 35.076, 129.067 35.076, 129.067 35.076, 129.068 35.076,...>}
# {'osmid': 761780964, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 78.436, 'geometry': <LINESTRING (129.066 35.076, 129.067 35.076, 129.067 35.076, 129.067 35.076,...>}
# {'osmid': 761780964, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 108.394, 'geometry': <LINESTRING (129.066 35.076, 129.066 35.076, 129.066 35.076, 129.066 35.076,...>}
# {'osmid': 761780965, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 42.07099999999999, 'geometry': <LINESTRING (129.066 35.076, 129.066 35.076, 129.066 35.076, 129.066 35.076,...>}
# {'osmid': 761780965, 'highway': 'living_street', 'oneway': False, 'reversed': True, 'length': 42.071, 'geometry': <LINESTRING (129.067 35.076, 129.067 35.076, 129.067 35.076, 129.067 35.076,...>}
# {'osmid': 718305473, 'oneway': False, 'name': '대교로40번길', 'highway': 'secondary', 'reversed': True, 'length': 23.061}
# {'osmid': 117608596, 'oneway': True, 'highway': 'secondary_link', 'reversed': False, 'length': 153.84, 'geometry': <LINESTRING (129.041 35.094, 129.04 35.095, 129.04 35.095, 129.04 35.095, 12...>}
# {'osmid': [718305472, 718305473], 'oneway': False, 'name': ['대교로46번길', '대교로40번길'], 'highway': 'secondary', 'reversed': False, 'length': 197.52, 'geometry': <LINESTRING (129.041 35.094, 129.041 35.095, 129.043 35.095)>}
# {'osmid': 117608578, 'name': '남항로9번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 54.388}
# {'osmid': 777392698, 'name': '남항로10번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 55.543}
# {'osmid': 796491756, 'name': '남항로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 82.846}
# {'osmid': 796491756, 'name': '남항로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 58.986}
# {'osmid': 117608564, 'name': '태종로105번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 49.095}
# {'osmid': 117608564, 'name': '태종로105번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 58.933}
# {'osmid': 500097052, 'name': '절영로19번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 54.393}
# {'osmid': 500097052, 'name': '절영로19번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 70.612}
# {'osmid': 117608554, 'name': '태종로99번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 49.194}
# {'osmid': 117608554, 'name': '태종로99번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 58.769}
# {'osmid': 500097052, 'name': '절영로19번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 54.847}
# {'osmid': 500097052, 'name': '절영로19번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 54.393}
# {'osmid': 117608589, 'name': '절영로13번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 29.919}
# {'osmid': 117608589, 'name': '절영로13번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 50.834}
# {'osmid': 511900572, 'oneway': True, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 108.476}
# {'osmid': 37396918, 'name': '동삼남로', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 49.725}
# {'osmid': 37396918, 'name': '동삼남로', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 49.397999999999996, 'geometry': <LINESTRING (129.067 35.077, 129.067 35.077, 129.067 35.078)>}
# {'osmid': 458100194, 'name': '장수4길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 88.57300000000001, 'geometry': <LINESTRING (129.067 35.077, 129.067 35.078, 129.067 35.078, 129.067 35.078,...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 53.65}
# {'osmid': 122355920, 'name': '태종로292번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 433.59900000000005, 'geometry': <LINESTRING (129.058 35.098, 129.058 35.098, 129.058 35.098, 129.058 35.098,...>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 130.671, 'geometry': <LINESTRING (129.058 35.098, 129.059 35.098, 129.059 35.098, 129.059 35.097)>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 49.239000000000004, 'geometry': <LINESTRING (129.067 35.09, 129.067 35.09, 129.067 35.09)>}
# {'osmid': 449880639, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 17.889, 'geometry': <LINESTRING (129.067 35.09, 129.067 35.09, 129.067 35.09)>}
# {'osmid': 777381209, 'name': '태종로422번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 70.943, 'geometry': <LINESTRING (129.067 35.09, 129.067 35.09, 129.067 35.09, 129.067 35.09, 129...>}
# {'osmid': 777381211, 'name': '태종로', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 51.815}
# {'osmid': 777381209, 'name': '태종로422번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 70.94300000000001, 'geometry': <LINESTRING (129.067 35.09, 129.067 35.09, 129.067 35.09, 129.067 35.09, 129...>}
# {'osmid': [777381210, 500097020], 'name': '태종로422번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 298.4820000000001, 'geometry': <LINESTRING (129.067 35.09, 129.067 35.089, 129.068 35.089, 129.068 35.089, ...>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 176.432, 'geometry': <LINESTRING (129.081 35.066, 129.081 35.066, 129.081 35.067, 129.081 35.067,...>}
# {'osmid': 268369734, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 38.275999999999996, 'geometry': <LINESTRING (129.081 35.066, 129.081 35.066, 129.081 35.066)>}
# {'osmid': 268374982, 'name': '하리서길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 151.667, 'geometry': <LINESTRING (129.081 35.066, 129.081 35.066, 129.082 35.066, 129.082 35.066,...>}
# {'osmid': 268374966, 'name': '아랫서발길37번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 34.676}
# {'osmid': 268374975, 'name': '태종로802번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 60.487}
# {'osmid': 268374975, 'name': '태종로802번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 83.969, 'geometry': <LINESTRING (129.079 35.065, 129.079 35.065, 129.079 35.065)>}
# {'osmid': 117608566, 'name': '절영로29번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 70.837}
# {'osmid': 117608566, 'name': '절영로29번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 54.859}
# {'osmid': 777392686, 'name': '남항로41번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 53.461}
# {'osmid': 777392686, 'name': '남항로41번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 58.54}
# {'osmid': 117608560, 'name': '대평로27번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 56.84}
# {'osmid': 777392693, 'name': '대평로33번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 41.09}
# {'osmid': 777392693, 'name': '대평로33번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 67.395}
# {'osmid': 777392671, 'name': '개량2길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 233.108, 'geometry': <LINESTRING (129.05 35.09, 129.051 35.092, 129.051 35.092)>}
# {'osmid': 777392672, 'name': '개량1길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 10.105}
# {'osmid': 777392671, 'name': '개량2길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 233.108, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.05 35.09)>}
# {'osmid': 777392672, 'name': '개량1길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 285.223, 'geometry': <LINESTRING (129.051 35.092, 129.051 35.092, 129.051 35.092, 129.051 35.091,...>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 255.38900000000004, 'geometry': <LINESTRING (129.049 35.09, 129.049 35.091, 129.049 35.091, 129.05 35.091, 1...>}
# {'osmid': 165393189, 'name': '봉래길', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 30.315, 'geometry': <LINESTRING (129.049 35.09, 129.049 35.09, 129.049 35.09, 129.049 35.09)>}
# {'osmid': 777392672, 'name': '개량1길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 285.223, 'geometry': <LINESTRING (129.049 35.09, 129.049 35.09, 129.049 35.09, 129.049 35.091, 12...>}
# {'osmid': 674027666, 'name': '대평남로51번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 36.446}
# {'osmid': 674027666, 'name': '대평남로51번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 34.795}
# {'osmid': 777392691, 'name': '대평남로51번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 89.735, 'geometry': <LINESTRING (129.032 35.092, 129.032 35.092, 129.032 35.092, 129.032 35.092)>}
# {'osmid': 117608562, 'name': '절영로101번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 137.126}
# {'osmid': 511894550, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 68.175}
# {'osmid': 511894550, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 11.816}
# {'osmid': 777392701, 'name': '절영로102번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 111.216}
# {'osmid': 117608568, 'bridge': 'yes', 'oneway': True, 'name': '남항대교', 'highway': 'trunk', 'reversed': False, 'length': 88.095, 'geometry': <LINESTRING (129.037 35.081, 129.038 35.082, 129.038 35.082)>}
# {'osmid': 117608565, 'name': '절영로35번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 70.232}
# {'osmid': 117608565, 'name': '절영로35번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 55.717}
# {'osmid': 777392686, 'name': '남항로41번길', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 75.792}
# {'osmid': 777392686, 'name': '남항로41번길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 53.461}
# {'osmid': 165393973, 'oneway': True, 'name': '해양로', 'highway': 'secondary', 'reversed': False, 'length': 98.554}
# {'osmid': 165386546, 'oneway': True, 'name': '영선대로', 'highway': 'trunk_link', 'reversed': False, 'length': 31.813}
# {'osmid': 165386548, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': False, 'length': 29.789}
# {'osmid': 165386548, 'oneway': False, 'name': '절영로', 'highway': 'secondary', 'reversed': True, 'length': 29.738}
# {'osmid': 117608570, 'name': '해님1길', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 130.737}
# {'osmid': 165386546, 'oneway': True, 'name': '영선대로', 'highway': 'trunk_link', 'reversed': False, 'length': 53.399}
# {'osmid': 800591375, 'name': '영선대로28번길', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 9.91}
# {'osmid': 800591375, 'name': '영선대로28번길', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 18.806}
# {'osmid': 468464868, 'oneway': True, 'name': '영선대로', 'highway': 'secondary', 'reversed': False, 'length': 21.346, 'geometry': <LINESTRING (129.04 35.084, 129.04 35.084, 129.04 35.084)>}
# {'osmid': 165393180, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': False, 'length': 155.446, 'geometry': <LINESTRING (129.062 35.085, 129.063 35.084, 129.063 35.084, 129.063 35.083)>}
# {'osmid': 165393180, 'name': '와치로', 'highway': 'secondary', 'oneway': False, 'reversed': True, 'length': 343.844, 'geometry': <LINESTRING (129.062 35.085, 129.062 35.085, 129.062 35.085, 129.061 35.085,...>}
# {'osmid': 835267864, 'highway': 'living_street', 'oneway': False, 'reversed': False, 'length': 272.99600000000004, 'geometry': <LINESTRING (129.062 35.085, 129.063 35.086, 129.064 35.086, 129.064 35.086)>}
# {'osmid': 268374969, 'name': '동삼오션로', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 472.598, 'geometry': <LINESTRING (129.083 35.068, 129.084 35.068, 129.084 35.068, 129.084 35.07, ...>}
# {'osmid': 268374969, 'name': '동삼오션로', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 124.129, 'geometry': <LINESTRING (129.083 35.068, 129.083 35.068, 129.083 35.068, 129.082 35.068)>}
# {'osmid': 268374969, 'name': '동삼오션로', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 183.406, 'geometry': <LINESTRING (129.083 35.068, 129.083 35.069, 129.082 35.069)>}
# {'osmid': 37400885, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': True, 'length': 66.198}
# {'osmid': 37400885, 'oneway': False, 'lanes': '2', 'name': '와치로', 'highway': 'secondary', 'reversed': False, 'length': 336.84399999999994, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.073, 129.075 35.072,...>}
# {'osmid': 994830770, 'oneway': True, 'highway': 'secondary_link', 'reversed': False, 'length': 38.845, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.073, 129.075 35.073)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': False, 'length': 58.596999999999994, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.073)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}

# %%
for nodes in G.nodes() :
  print(data)
# Out:
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# ...
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}
# {'osmid': 281779718, 'oneway': False, 'name': '태종로', 'highway': 'secondary', 'reversed': True, 'length': 73.429, 'geometry': <LINESTRING (129.075 35.073, 129.075 35.073, 129.075 35.072)>}

# %% [markdown]
# ### *quiz1: 주소로부터 지도를 출력하시기 바랍니다

# %%
address = "156, Saecheonnyeon-gil, Yeongdo-gu, Busan, Republic of Korea" #@param {type:"string"}
G = ox.graph_from_address(address, network_type="walk")
fig, ax = ox.plot_graph(G)

# %% [markdown]
# # 도로의 속성 값에 따라서 다른 형태의 도로로 표시하기

# %% [markdown]
# 아래 링크에서 다양한 도로정보를 살펴볼수가 있다.
# https://wiki.openstreetmap.org/wiki/Key:highway

# %%
# edge의 타입 따라서 도로에 대한 색깔 다르게 표시하기
hwy_colors = {'footway': 'blue',
              'residential': 'red',
              'cycleway': 'orange',
              'service': 'sienna',
              'living street': 'red',
              'secondary': 'green',
              'pedestrian': 'grey'}

# %%
# 엣지를 탐색
def find_edges(G, hwys):
    edges = []
    for u, v, k, data in G.edges(keys=True, data='highway'):
        check1 = isinstance(data, str) and data not in hwys
        check2 = isinstance(data, list) and all([d not in hwys for d in data])
        if check1 or check2:
            edges.append((u, v, k))
    return set(edges)

# %%
# hwy 이 정해지지 않은 경우는 black
G_tmp = G.copy()
G_tmp.remove_edges_from(G.edges - find_edges(G, hwy_colors.keys()))
m = ox.plot_graph_folium(G_tmp, popup_attribute='highway', weight=2, color='black')

# 지도 위에서 Hwy_colors에서 정해진 타입에 따라 추가적인 edge를 그림
for hwy, color in hwy_colors.items():
    G_tmp = G.copy()
    G_tmp.remove_edges_from(find_edges(G_tmp, [hwy]))
    if G_tmp.edges:
        m = ox.plot_graph_folium(G_tmp,
                                 graph_map=m,
                                 popup_attribute='highway',
                                 weight=2,
                                 color=color)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad0f548eaf6afa70684e85cf9bd7774b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad0f548eaf6afa70684e85cf9bd7774b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad0f548eaf6afa70684e85cf9bd7774b = L.map(
#                 &quot;map_ad0f548eaf6afa70684e85cf9bd7774b&quot;,
#                 {
#                     center: [35.088311439863496, 129.04489489726728],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b0a4ef55b4b74cc8c107c91daa346fe = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad0f548eaf6afa70684e85cf9bd7774b);
#
#
#             var poly_line_a121d7edec3dada502a26e687ea9723a = L.polyline(
#                 [[35.0920623, 129.0461608], [35.0915388, 129.0458763]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ad0f548eaf6afa70684e85cf9bd7774b);
#
#
#         var popup_8192b904d5793fabce298c5fa9418734 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8df8c470af745289b974fbb3c8868215 = $(`&lt;div id=&quot;html_8df8c470af745289b974fbb3c8868215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot;tertiary&quot;&lt;/div&gt;`)[0];
#                 popup_8192b904d5793fabce298c5fa9418734.setContent(html_8df8c470af745289b974fbb3c8868215);
#
#
#
#         poly_line_a121d7edec3dada502a26e687ea9723a.bindPopup(popup_8192b904d5793fabce298c5fa9418734)
#         ;
#
#
#
#
#             var poly_line_b3392070aad50af0cc45813bbfe2fe21 = L.polyline(
#                 [[35.0920623, 129.0461608], [35.0922262, 129.0459659], [35.0923455, 129.045671]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ad0f548eaf6afa70684e85cf9bd7774b);
#
#
#         var popup_5a44578f73c9c58d52df53ef5e086f4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b0e6227fe1c233fde48405cdb91b0e3 = $(`&lt;div id=&quot;html_0b0e6227fe1c233fde48405cdb91b0e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot;tertiary&quot;&lt;/div&gt;`)[0];
#                 popup_5a44578f73c9c58d52df53ef5e086f4e.setContent(html_0b0e6227fe1c233fde48405cdb91b0e3);
#
#
#
#         poly_line_b3392070aad50af0cc45813bbfe2fe21.bindPopup(popup_5a44578f73c9c58d52df53ef5e086f4e)
#         ;
#
#
#
#
#             var poly_line_ec442daf9330cc519f799ac71b639b4c = L.polyline(
#                 [[35.0920623, 129.0461608], [35.0923298, 129.0463254], [35.0926283, 129.046481]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ad0f548eaf6afa70684e85cf9bd7774b);
#
#
#         var popup_16559a1c0397f8397c4b8b0d7ea2121c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c14b7f099a015b18acdee89d23a8c5f = $(`&lt;div id=&quot;html_2c14b7f099a015b18acdee89d23a8c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot;tertiary&quot;&lt;/div&gt;`)[0];
#                 popup_16559a1c0397f8397c4b8b0d7ea2121c.setContent(html_2c14b7f099a015b18acdee89d23a8c5f);

# %% [markdown]
# ### *quiz2: 도보(walk)을 다른 색깔과 함께 추가해보시오.

# %% [markdown]
# # 기본적인 도로네트워크

# %%
# what sized area does our network cover in square meters?
G_proj = ox.project_graph(G)
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m
# Out:
# 3421345.707854155

# %%
# show some basic stats about the network
ox.basic_stats(G_proj, area=graph_area_m, clean_int_tol=15)
# Out:
# {'n': 437,
#  'm': 1362,
#  'k_avg': 6.233409610983982,
#  'edge_length_total': 109286.36599999995,
#  'edge_length_avg': 80.23962261380319,
#  'streets_per_node_avg': 3.203661327231121,
#  'streets_per_node_counts': {0: 0, 1: 31, 2: 0, 3: 259, 4: 143, 5: 4},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.07093821510297482,
#   2: 0.0,
#   3: 0.5926773455377574,
#   4: 0.32723112128146453,
#   5: 0.009153318077803204},
#  'intersection_count': 406,
#  'street_length_total': 54643.183000000034,
#  'street_segment_count': 681,
#  'street_length_avg': 80.23962261380328,
#  'circuity_avg': 1.0417830045004108,
#  'self_loop_proportion': 0.0,
#  'clean_intersection_count': 283,
#  'node_density_km': 127.72751931990044,
#  'intersection_density_km': 118.66675707981597,
#  'edge_density_km': 31942.508980930674,
#  'street_density_km': 15971.254490465353,
#  'clean_intersection_density_km': 82.71599077238403}

# %%
# save graph to disk as geopackage (for GIS) or graphml file (for gephi etc)
ox.save_graph_geopackage(G, filepath="./data/mynetwork.gpkg")
ox.save_graphml(G, filepath="./data/mynetwork.graphml")

# %% [markdown]
# # 도로의 중심성을 시각화

# %%
# convert graph to line graph so edges become nodes and vice versa
edge_centrality = nx.closeness_centrality(nx.line_graph(G))
nx.set_edge_attributes(G, edge_centrality, "edge_centrality")

# %%
# color edges in original graph with closeness centralities from line graph
ec = ox.plot.get_edge_colors_by_attr(G, "edge_centrality", cmap="inferno")
fig, ax = ox.plot_graph(G, edge_color=ec, edge_linewidth=2, node_size=0)

# %% [markdown]
# ## quiz3: 부산의 다른 지역(번화가 중심성)을 진행하길 바랍니다. 이때 node_centrality와 차이가 있는지 확인해 보세요

# %% [markdown]
# # 경로(Routing) 확인

# %%
# impute missing edge speeds and calculate edge travel times with the speed module
G = ox.speed.add_edge_speeds(G)
G = ox.speed.add_edge_travel_times(G)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-0735c1cd005a> in <cell line: 2>()
#       1 # impute missing edge speeds and calculate edge travel times with the speed module
# ----> 2 G = ox.speed.add_edge_speeds(G)
#       3 G = ox.speed.add_edge_travel_times(G)
#
# /usr/local/lib/python3.10/dist-packages/osmnx/speed.py in add_edge_speeds(G, hwy_speeds, fallback, precision, agg)
#     107     # caller did not pass in hwy_speeds or fallback arguments
#     108     if pd.isnull(speed_kph).all():
# --> 109         raise ValueError(
#     110             (
#     111                 "this graph's edges have no preexisting `maxspeed` "
#
# ValueError: this graph's edges have no preexisting `maxspeed` attribute values so you must pass `hwy_speeds` or `fallback` arguments.

# %%
# get the nearest network nodes to two lat/lng points with the distance module 
orig = ox.distance.nearest_nodes(G, X=128.96755631796773, Y=35.11601594137444) 
dest = ox.distance.nearest_nodes(G, X=128.96517223758627, Y=35.046698756214056)

# %%
# find the shortest path between nodes, minimizing travel time, then plot it
route = ox.shortest_path(G, orig, dest, weight="travel_time")
fig, ax = ox.plot_graph_route(G, route, node_size=0)

# %%
routes  = ox.k_shortest_paths(G, orig, dest, 3, weight="travel_time")
paths = [r for r in routes]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-831632890303> in <cell line: 2>()
#       1 routes  = ox.k_shortest_paths(G, orig, dest, 3, weight="travel_time")
# ----> 2 paths = [r for r in routes]
#
# <ipython-input-32-831632890303> in <listcomp>(.0)
#       1 routes  = ox.k_shortest_paths(G, orig, dest, 3, weight="travel_time")
# ----> 2 paths = [r for r in routes]
#
# /usr/local/lib/python3.10/dist-packages/osmnx/distance.py in k_shortest_paths(G, orig, dest, k, weight)
#     469         is a list of node IDs.
#     470     """
# --> 471     paths_gen = nx.shortest_simple_paths(utils_graph.get_digraph(G, weight), orig, dest, weight)
#     472     for path in itertools.islice(paths_gen, 0, k):
#     473         yield path
#
# /usr/local/lib/python3.10/dist-packages/osmnx/utils_graph.py in get_digraph(G, weight)
#     315     # minimum "weight" attribute value
#     316     for u, v in set(parallels):
# --> 317         k_min, _ = min(G.get_edge_data(u, v).items(), key=lambda x: x[1][weight])
#     318         to_remove.extend((u, v, k) for k in G[u][v] if k != k_min)
#     319
#
# /usr/local/lib/python3.10/dist-packages/osmnx/utils_graph.py in <lambda>(x)
#     315     # minimum "weight" attribute value
#     316     for u, v in set(parallels):
# --> 317         k_min, _ = min(G.get_edge_data(u, v).items(), key=lambda x: x[1][weight])
#     318         to_remove.extend((u, v, k) for k in G[u][v] if k != k_min)
#     319
#
# KeyError: 'travel_time'

# %%
# find the k-shortest paths between nodes, minimizing travel time, then plot it
fig, ax = ox.plot_graph_routes(G, paths, route_colors=['r','b','g'], route_linewidth=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f75b65e66977> in <cell line: 2>()
#       1 # find the k-shortest paths between nodes, minimizing travel time, then plot it
# ----> 2 fig, ax = ox.plot_graph_routes(G, paths, route_colors=['r','b','g'], route_linewidth=3)
#
# NameError: name 'paths' is not defined

# %%
# how long is our route in meters?
edge_lengths = ox.utils_graph.get_route_edge_attributes(G, route, "length")
round(sum(edge_lengths))
# Out:
# 2496

# %%
# how far is it between these two nodes as the crow flies?
# use OSMnx's vectorized great-circle distance (haversine) function
orig_x = G.nodes[orig]["x"]
orig_y = G.nodes[orig]["y"]
dest_x = G.nodes[dest]["x"]
dest_y = G.nodes[dest]["y"]
round(ox.distance.great_circle_vec(orig_y, orig_x, dest_y, dest_x))
# Out:
# 1789

# %% [markdown]
# ### quiz5: networkx알고리즘 다양한 routing 알고리즘을 가지고 있습니다.
# https://networkx.org/documentation/stable/reference/algorithms/shortest_paths.html
# 위 링크를 참고하여 다양한 routing 정보에 지도에 표현하길 바랍니다.

# %% [markdown]
# ## 1. Fast nearest node/edge search with OSMnx
#
# The nearest_nodes and nearest_edges functions take arrays of x and y (or lng/lat) coordinates and return the nearest node/edge to each.

# %%
Gp = ox.project_graph(G)

# %%
# randomly sample n points spatially-constrained to the network's geometry
points = ox.utils_geo.sample_points(ox.get_undirected(Gp), n=100)
X = points.x.values
Y = points.y.values
X0 = X.mean()
Y0 = Y.mean()

# %%
# find each nearest node to several points, and optionally return distance
nodes, dists = ox.nearest_nodes(Gp, X, Y, return_dist=True)

# %%
# or, find the nearest node to a single point
node = ox.nearest_nodes(Gp, X0, Y0)
node
# Out:
# 4795892887

# %%
# find each nearest edge to several points, and optionally return distance
edges, dists = ox.nearest_edges(Gp, X, Y, return_dist=True)

# %%
# find the nearest edge to a single point
edge = ox.nearest_edges(Gp, X0, Y0)
edge
# Out:
# (6611505598, 4795892887, 0)

# %% [markdown]
# # 여정시간 계산 및 시각화

# %%
# !pip install descartes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting descartes
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descartes) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)
# Installing collected packages: descartes
# Successfully installed descartes-1.1.0

# %%
import geopandas as gpd
from descartes import PolygonPatch
from shapely.geometry import LineString
from shapely.geometry import Point
from shapely.geometry import Polygon

# %% [markdown]
# network_type: One of ‘walk’, ‘bike’, ‘drive’, ‘drive_service’, ‘all’, or ‘all_private’.

# %%
# configure the place, network type, trip times, and travel speed
address = "Hadan-dong, Saha-gu, Busan, Korea"
network_type = "walk"
trip_times = [5, 10, 15, 20, 25, 30]  # 분 단위의 여행시간, 5분거리내
travel_speed = 4.5  # 걷는 속도 (km/hour)

# %%
# 위치에 따른 지도 가져오기
G = ox.graph_from_address( address, network_type=network_type)

# %%
# 원하는 지점과 해당 지도에 대해서 그래프 
gdf_nodes = ox.graph_to_gdfs(G, edges=False)
# x, y = gdf_nodes["geometry"].unary_union.centroid.xy # 지도 중심점 좌표
# 동아대학교의 위경도 좌표: lat -> 위도 x , 경도->lon y
x = 128.96817249950897
y = 35.11755694483541
center_node = ox.distance.nearest_nodes(G, x, y)
G = ox.project_graph(G)

# %%
# 계산을 위한 edges에 속성값을 넣습니다.
meters_per_minute = travel_speed * 1000 / 60  # km per hour to m per minute
for _, _, _, data in G.edges(data=True, keys=True):
    data["time"] = data["length"] / meters_per_minute

# %%
# get one color for each isochrone
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap="plasma", start=0, return_hex=True)

# %%
# 등시성에 따라 노드에 색칠
node_colors = {}
for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
    subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance="time")
    for node in subgraph.nodes():
        node_colors[node] = color
nc = [node_colors[node] if node in node_colors else "none" for node in G.nodes()]
ns = [15 if node in node_colors else 0 for node in G.nodes()]
fig, ax = ox.plot_graph(
    G,
    node_color=nc,
    node_size=ns,
    node_alpha=0.8,
    edge_linewidth=0.2,
    edge_color="#999999",
)

# %%
# 등시성의 polygon 구현
isochrone_polys = []
for trip_time in sorted(trip_times, reverse=True):
    subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance="time")
    node_points = [Point((data["x"], data["y"])) for node, data in subgraph.nodes(data=True)]
    bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
    isochrone_polys.append(bounding_poly)

# %%
"""
  CustomPolygonPath 
"""

from matplotlib.patches import PathPatch
from matplotlib.path import Path
from numpy import asarray, concatenate, ones

def CustomPolygonPath(polygon):
    """Constructs a compound matplotlib path from a Shapely or GeoJSON-like
    geometric object"""

    def coding(ob):
        # The codes will be all "LINETO" commands, except for "MOVETO"s at the
        # beginning of each subpath
        n = len(getattr(ob, 'coords', None) or ob)
        vals = ones(n, dtype=Path.code_type) * Path.LINETO
        vals[0] = Path.MOVETO
        return vals

    if hasattr(polygon, 'geom_type'):  # Shapely
        ptype = polygon.geom_type
        if ptype == 'Polygon':
            polygon = [Polygon(polygon)]
        elif ptype == 'MultiPolygon':
            polygon = [Polygon(p) for p in polygon]
        else:
            raise ValueError(
                "A polygon or multi-polygon representation is required")

    else:  # GeoJSON
        polygon = getattr(polygon, '__geo_interface__', polygon)
        ptype = polygon["type"]
        if ptype == 'Polygon':
            polygon = [Polygon(polygon)]
        elif ptype == 'MultiPolygon':
            polygon = [Polygon(p) for p in polygon['coordinates']]
        else:
            raise ValueError(
                "A polygon or multi-polygon representation is required")

    # convert `t.exterior` into `t.exterior.coords`
    # contributed by https://github.com/jsk0910
    vertices = concatenate([
        concatenate([asarray(t.exterior.coords)[:, :2]] +
                    [asarray(r)[:, :2] for r in t.interiors])
        for t in polygon])
    codes = concatenate([
        concatenate([coding(t.exterior)] +
                    [coding(r) for r in t.interiors]) for t in polygon])

    return Path(vertices, codes)

def CustomPolygonPatch(polygon, **kwargs):
    # 변경된 내용
    # 새로운 동작을 수행하는 코드
    return PathPatch(CustomPolygonPath(polygon), **kwargs)

# %%
# 등시성에 따른 네트워크를 표기
fig, ax = ox.plot_graph(
    G, show=False, close=False, edge_color="#999999", edge_alpha=0.2, node_size=0
)
for polygon, fc in zip(isochrone_polys, iso_colors):
    patch = CustomPolygonPatch(polygon, fc=fc, ec="none", alpha=0.6, zorder=-1 )
    # patch = PolygonPatch(polygon, fc=fc, ec="none", alpha=0.6, zorder=-1)
    ax.add_patch(patch)
plt.show()

# %%
def make_iso_polys(G, edge_buff=25, node_buff=50, infill=False):
    isochrone_polys = []
    for trip_time in sorted(trip_times, reverse=True):
        subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance="time")

        node_points = [Point((data["x"], data["y"])) for node, data in subgraph.nodes(data=True)]
        nodes_gdf = gpd.GeoDataFrame({"id": list(subgraph.nodes)}, geometry=node_points)
        nodes_gdf = nodes_gdf.set_index("id")

        edge_lines = []
        for n_fr, n_to in subgraph.edges():
            f = nodes_gdf.loc[n_fr].geometry
            t = nodes_gdf.loc[n_to].geometry
            edge_lookup = G.get_edge_data(n_fr, n_to)[0].get("geometry", LineString([f, t]))
            edge_lines.append(edge_lookup)

        n = nodes_gdf.buffer(node_buff).geometry
        e = gpd.GeoSeries(edge_lines).buffer(edge_buff).geometry
        all_gs = list(n) + list(e)
        new_iso = gpd.GeoSeries(all_gs).unary_union

        # try to fill in surrounded areas so shapes will appear solid and
        # blocks without white space inside them
        if infill:
            new_iso = Polygon(new_iso.exterior)
        isochrone_polys.append(new_iso)
    return isochrone_polys

# %%
isochrone_polys = make_iso_polys(G, edge_buff=25, node_buff=0, infill=True)
fig, ax = ox.plot_graph(
    G, show=False, close=False, edge_color="#999999", edge_alpha=0.2, node_size=0
)
for polygon, fc in zip(isochrone_polys, iso_colors):
    patch = CustomPolygonPatch(polygon, fc=fc, ec="none", alpha=0.7, zorder=-1)
    ax.add_patch(patch)
plt.show()

# %% [markdown]
# # YOUR WORK: Hyperlocal 찾기
# Definition: information oriented around a well-defined community with its primary focus directed toward the concerns of the population in that community.
#
# 슬세권이란 슬리퍼와 같은 편한 복장으로 각종 여가·편의시설을 이용할 수 있는 주거 권역을 가리킨다. 일상생활에 필요한 대부분을 인근에서 해결할 수 있어 주거 편의성이 높은 만큼 젊은 세대가 주 수요층인 오피스텔 시장에서 선호도가 높게 나타나고 있다.
#
# 출처 : 국토일보(http://www.ikld.kr)

# %% [markdown]
# 주요 속성: 도보거리
# A comparison of gait biomechanics of flip-flops,
# sandals, barefoot and shoes
# https://jfootankleres.biomedcentral.com/track/pdf/10.1186/1757-1146-6-45.pdf
